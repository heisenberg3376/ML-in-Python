# %%
import pandas as pd
pd.set_option('display.max_columns',False)


df = pd.read_csv('mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises  ... ring-number ring-type spore-print-color population habitat
# 0     p         x           s         n       t  ...           o         p                 k          s       u
# 1     e         x           s         y       t  ...           o         p                 n          n       g
# 2     e         b           s         w       t  ...           o         p                 n          n       m
# 3     p         x           y         w       t  ...           o         p                 k          s       u
# 4     e         x           s         g       f  ...           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in df.columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  ...  ring-number  ring-type  spore-print-color  population  habitat
# 0      1          5            2          4        1  ...            1          4                  2           3        5
# 1      0          5            2          9        1  ...            1          4                  3           2        1
# 2      0          0            2          8        1  ...            1          4                  3           2        3
# 3      1          5            3          8        1  ...            1          4                  2           3        5
# 4      0          5            2          3        0  ...            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
X = df.drop(['class'],axis=1)
y = df['class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# 100 % accuracy
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
import ipywidgets
from matplotlib import style
plt.rcParams['figure.figsize'] = (20, 10)

style.use('ggplot')

# %matplotlib inline
class_names = ['poisonous','edible']
def plot_fun(clf):
    plt.title('This is the Decision Tree')
    plot_tree(clf,filled=True,feature_names=X.columns,class_names=class_names,label=None)
    p = plt.figure(figsize=(25,20))
    plt.show()
    
plot_fun(clf)
